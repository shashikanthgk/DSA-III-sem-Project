# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = cv2.imread("testkmeans2.png")
img.shape
# Out:
# (324, 528, 3)

# %%
img = cv2.resize(img,(120,120))

# %%
image = img.reshape(3,img.shape[0],img.shape[1])
image.shape
# Out:
# (3, 120, 120)

# %%
out = open("image_pixel.txt", "w")
for i in range(image.shape[1]):
    for j in range(image.shape[2]):
        line = str(image[0][i][j])+" "+str(image[1][i][j])+" "+str(image[2][i][j])
        out.write(line)
        out.write("\n")

# %%
plt.axis("off")
plt.imshow(cv2.cvtColor(image.reshape(img.shape[0],img.shape[1],3), cv2.COLOR_BGR2RGB))
plt.show()

# %%
#before runnig th below block please run the kmeansclustering.cpp file

# %%
s=[]
centroids = []
x= 1
print(image.shape)

new_image = np.zeros(shape=(3,image.shape[1],image.shape[2]))
with open("/home/shashikanth/DSA_project/points_cluster.txt") as f:
    for line in f:
        s.append(line.split(" "))
        
        
with open("/home/shashikanth/DSA_project/centroids.txt") as f:
    for line in f:
        centroids.append(line.split(" "))
        
        
for i in range(len(s)):
       for j in range(len(s[i])):
        if not s[i][j] == '\n':
            print(centroids[i][0])
            print(centroids[i][1])
            print(centroids[i][2])

#     pixel = float(s[i][j])
            new_image[0][int((pixel-1)/image.shape[2])][int((pixel-1)%(image.shape[2]))]=(float(centroids[i][0]));                         
            new_image[1][int((pixel-1)/image.shape[2])][int((pixel-1)%(image.shape[2]))]=(float(centroids[i][1]));
            new_image[2][int((pixel-1)/image.shape[2])][int((pixel-1)%(image.shape[2]))]=(float(centroids[i][2]));
          

        
print(new_image.shape)
# Out:
# (3, 120, 120)
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# 46.5508
# 59.6562
# 33.6641
# ...

# %%
centroids
# Out:
# [['59.6562', '33.6641', '46.5508', '\n'],
#  ['236.46', '215.802', '5.37186', '\n'],
#  ['57.1644', '200.581', '45.4651', '\n'],
#  ['31.6064', '141.192', '227.671', '\n'],
#  ['186.107', '90.3527', '248.846', '\n'],
#  ['158.638', '202.383', '197.121', '\n']]

# %%
new = new_image.reshape(image.shape[1],image.shape[2],3)

# %%
# img = np.array(new, dtype=np.uint8)
plt.axis("off")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
